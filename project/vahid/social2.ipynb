# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('data.csv')

# %%
df
# Out:
#                        Id  Label  timeset  \
# 0                17461978      0      NaN
# 1     1297437077403885568      1      NaN
# 2                17685258      0      NaN
# 3                15750898      0      NaN
# 4              1659167666      1      NaN
# ...                   ...    ...      ...
# 2600   920348493583040512      1      NaN
# 2601            110312278      0      NaN
# 2602           2224798981      1      NaN
# 2603           2342939094      1      NaN
# 2604            131638816      1      NaN
#
#                                             name  follower count  \
# 0                                           SHAQ        15349596
# 1                               Jennifer Fishpaw               0
# 2                                  Brad Parscale          762839
# 3                               FOX 13 Tampa Bay          327587
# 4     Vonte The Plug :microphone::electric_plug:           13324
# ...

# %%
sns.scatterplot(data=df, x='eigencentrality',y='pageranks', hue='Label')
# Out:
# <AxesSubplot:xlabel='eigencentrality', ylabel='pageranks'>

# %%
sns.heatmap(df.corr(),cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df2=df.drop(['timeset','name','Id','harmonicclosnesscentrality'],axis=1)

# %%
df2
# Out:
#       Label  follower count  friends count  indegree  outdegree  Degree  \
# 0         0        15349596            692         3          0       3
# 1         1               0             44         0          3       3
# 2         0          762839            475         3          1       4
# 3         0          327587           4801         0          0       0
# 4         1           13324            647         1          0       1
# ...     ...             ...            ...       ...        ...     ...
# 2600      1               6             62         0          4       4
# 2601      0         3791160            393         1          0       1
# 2602      1             203            437         0          0       0
# 2603      1              11             11         0          1       1
# 2604      1            2318            613         0          1       1
#
#       Eccentricity  closnesscentrality  betweenesscentrality  eigencentrality  \
# ...

# %%
sns.heatmap(df2.corr(),cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=df, x='Degree',y='outdegree', hue='Label')
# Out:
# <AxesSubplot:xlabel='Degree', ylabel='outdegree'>
